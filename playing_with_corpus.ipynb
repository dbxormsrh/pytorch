# %%
import pandas as pd

# %%
import json
import time

# %%
import random

# %%
import pprint

# %%
#세계/NNG
#넓히/VV + 어/EC
print(('세계/NNG').rsplit('/',1))
('넓히/VV + 어/EC').rsplit('/',1)
word = 'hello'
i = 'i'
ello = 'ello'

word.replace(ello, i)
word
# Out:
# ['세계', 'NNG']
# 'hello'

# %%
df = pd.read_csv("../NIKL_MP_CSV/NXMP1902008040_5.csv")

# %%
df = df.dropna()

# %%
sentence_id_list = df.drop_duplicates("sentence_id")['sentence_id'].to_list()

# %%
sentence_id_list = random.sample(sentence_id_list, 100)

# %% [markdown]
# -------------------------------------------------------------

# %%
df2 = pd.read_csv("../NIKL_MP_CSV/NXMP1902008040_2.csv")

# %%
df2 = df2.dropna()

# %%
x = df[df['position'] >= 3].drop_duplicates("sentence_id")['sentence_id']

# %%
sentence_id_list2 = df2.drop_duplicates("sentence_id")['sentence_id'].to_list()

# %%
result = []
for sent_id in sentence_id_list:
    print(sent_id)
    sub_df = df[df['sentence_id'] == 'NWRW1800000037.33.5.3']
    word_id_list = sub_df['word_id'].unique()
    sentence = sub_df['sentence'].iloc[0]
    words = sentence.split()
    
    for word_id in word_id_list:
        word = words[word_id - 1]
        forms = ''.join(sub_df[sub_df['word_id'] == word_id]['form'].to_list())
        print(forms)
        word_pos = 0
        form_pos = 0
        while len(word) > word_pos:
            if word[word_pos] == forms[form_pos]:
                result.append((word[word_pos], forms[form_pos]))
                word_pos += 1
                form_pos += 1
            else:
                result.append((word[word_pos], (forms[form_pos], forms[form_pos + 1])))
                word_pos += 1
                form_pos += 2
                
    break
# Out:
# NWRW1800000040.88.7.4
# 취임행사에서
# 껌을
# 씹은
# 오바마
# 대통령에
# 대하아
# “부적절하다”는
# 비난도
# 있지만
# “소탈하다”
# “자연스럽ㄴ
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-13-27ca0c9af852> in <module>()
#      17         form_pos = 0
#      18         while len(word) > word_pos:
# ---> 19             if word[word_pos] == forms[form_pos]:
#      20                 result.append((word[word_pos], forms[form_pos]))
#      21                 word_pos += 1
#
# IndexError: string index out of range

# %%
i = 0
sent_list = []
result = {}
for sent_id in sentence_id_list:
    print(sent_id)
    result[sent_id] = {}
    sub_df = df[df['sentence_id'] == sent_id]
    word_id_list = sub_df['word_id'].unique()
    sentence = sub_df['sentence'].iloc[0]
    words = sentence.split(' ')
    
    for word_id in word_id_list:
        word = words[word_id - 1]
        forms = sub_df[sub_df['word_id'] == word_id]['form'].to_list()
        result[sent_id][word] = []
        word_df = sub_df[sub_df['word_id'] == word_id]
        for form in forms:
            label = word_df[word_df['form'] == form]['label'].iloc[0]
            result[sent_id][word].append((form, label))
#             if form == word[:len(form)]:
#                 result[sent_id][word].append(form)
#             else:
#                 try:
#                     if result[sent_id][-1][0] == word:
#                         result[sent_id][-1] += tuple(form)
#                     else:
#                         result[sent_id].append((word, form))
#                 except IndexError:
#                     print(f'IndexError : {word, form}')
#                     result[sent_id].append((word, form))
#                     continue
            
#             word = word.replace(form, '')
            
    i += 1
    if i > 10:
        break
# Out:
# NWRW1800000036.398.5.2
# NWRW1800000048.322.5.3
# NWRW1800000049.344.6.2
# NWRW1800000054.12.4.2
# NWRW1800000033.329.6.1
# NWRW1800000022.411.3.1
# NWRW1800000040.376.8.3
# NWRW1800000040.301.6.5
# NWRW1800000041.221.6.2
# NWRW1800000026.115.1.1
# NWRW1800000046.325.6.1

# %%
pprint.pprint(result)
result
# Out:
# {'NWRW1800000022.411.3.1': {'3대': [('3', 'SN'), ('대', 'NNG')],
#                             '경북': [('경북', 'NNP')],
#                             '경주의': [('경주', 'NNP'), ('의', 'JKG')],
#                             '고령의': [('고령', 'NNP'), ('의', 'JKG')],
#                             '그가': [('그', 'NP'), ('가', 'JKS')],
#                             '그린': [('그리', 'VV'), ('ㄴ', 'ETM')],
#                             '대가야': [('대가야', 'NNP')],
#                             '문화권인': [('문화', 'NNG'),
#                                      ('권', 'XSN'),
#                                      ('이', 'VCP'),
#                                      ('ㄴ', 'ETM')],
#                             '문화를': [('문화', 'NNG'), ('를', 'JKO')],
#                             '불교문화,': [('불교문화', 'NNG'), (',', 'SP')],
#                             '서정적인': [('서정', 'NNG'),
#                                      ('적', 'XSN'),
#                                      ('이', 'VCP'),
#                                      ('ㄴ', 'ETM')],
#                             '선보인다.': [('선보이', 'VV'), ('ㄴ다', 'EF'), ('.', 'SF')],
#                             '선비문화,': [('선비', 'NNG'),
#                                       ('문화', 'NNG'),
#                                       (',', 'SP')],
#                             '안동의': [('안동', 'NNP'), ('의', 'JKG')],
#                             '작품들을': [('작품', 'NNG'), ('들', 'XSN'), ('을', 'JKO')],
#                             '풍경으로': [('풍경', 'NNG'), ('으로', 'JKB')]},
#  'NWRW1800000026.115.1.1': {'[6·2': [('[', 'SS'),
#                                      ('6', 'SN'),
#                                      ('·', 'SP'),
#                                      ('2', 'SN')],
#                             '[충청]': [('[', 'SS'), ('충청', 'NNP'), (']', 'SS')],
#                             '김기호씨': [('김기호', 'NNP'), ('씨', 'NNB')],
#                             '보령시장': [('보령시장', 'NNG')],
#                             '지금…]': [('지금', 'MAG'), ('…', 'SE'), (']', 'SS')],
#                             '지방선거는': [('지방', 'NNG'),
#                                       ('선거', 'NNG'),
#                                       ('는', 'JX')],
#                             '출마': [('출마', 'NNG')]},
#  'NWRW1800000033.329.6.1': {'것으로': [('것', 'NNB'), ('으로', 'JKB')],
#                             '공군이': [('공군', 'NNG'), ('이', 'JKS')],
#                             '군': [('군', 'NNG')],
#                             '당국은': [('당국', 'NNG'), ('은', 'JX')],
#                             '대비하고': [('대비', 'NNG'), ('하', 'XSV'), ('고', 'EC')],
#                             '만일의': [('만일', 'NNG'), ('의', 'JKG')],
#                             '맞아': [('맞', 'VV'), ('아', 'EC')],
#                             '북한': [('북한', 'NNP')],
#                             '분석하면서도': [('분석', 'NNG'),
#                                        ('하', 'XSV'),
#                                        ('면서', 'EC'),
#                                        ('도', 'JX')],
#                             '사태에': [('사태', 'NNG'), ('에', 'JKB')],
#                             '있다.': [('있', 'VX'), ('다', 'EF'), ('.', 'SF')],
#                             '전투검열기간을': [('전투', 'NNG'),
#                                         ('검열', 'NNG'),
#                                         ('기간', 'NNG'),
#                                         ('을', 'JKO')],
#                             '철저히': [('철저히', 'MAG')],
#                             '최근': [('최근', 'MAG')],
#                             '출격훈련을': [('출격', 'NNG'),
#                                       ('훈련', 'NNG'),
#                                       ('을', 'JKO')],
#                             '하계': [('하계', 'NNG')],
#                             '하는': [('하', 'VV'), ('는', 'ETM')],
#                             '활발히': [('활발히', 'MAG')]},
#  'NWRW1800000036.398.5.2': {'“실제로': [('“', 'SS'), ('실제로', 'MAG')],
#                             '가입': [('가입', 'NNG')],
#                             '그를': [('그', 'NP'), ('를', 'JKO')],
#                             '기억을': [('기억', 'NNG'), ('을', 'JKO')],
#                             '다니는': [('다니', 'VV'), ('는', 'ETM')],
#                             '당시': [('당시', 'NNG')],
#                             '되는데,': [('되', 'VV'), ('는데', 'EC'), (',', 'SP')],
#                             '되살렸다.': [('되살리', 'VV'),
#                                       ('었', 'EP'),
#                                       ('다', 'EF'),
#                                       ('.', 'SF')],
#                             '만난': [('만나', 'VV'), ('ㄴ', 'ETM')],
#                             '많다고': [('많', 'VA'), ('다고', 'EC')],
#                             '받아서': [('받', 'VV'), ('아서', 'EC')],
#                             '브로커였다”고': [('브로커', 'NNG'),
#                                         ('이', 'VCP'),
#                                         ('었', 'EP'),
#                                         ('다', 'EF'),
#                                         ('”', 'SS'),
#                                         ('고', 'JKQ')],
#                             '사람은': [('사람', 'NNG'), ('은', 'JX')],
#                             '서명을': [('서명', 'NNG'), ('을', 'JKO')],
#                             '수가': [('수', 'NNG'), ('가', 'JKS')],
#                             '안': [('안', 'MAG')],
#                             '엄청나게': [('엄청나', 'VA'), ('게', 'EC')],
#                             '여기저기서': [('여기저기', 'NNG'), ('서', 'JKB')],
#                             '열명도': [('열', 'NR'), ('명', 'NNB'), ('도', 'JX')],
#                             '인사는': [('인사', 'NNG'), ('는', 'JX')],
#                             '장사하고': [('장사', 'NNG'), ('하', 'XSV'), ('고', 'EC')],
#                             '전형적인': [('전형', 'NNG'),
#                                      ('적', 'XSN'),
#                                      ('이', 'VCP'),
#                                      ('ㄴ', 'ETM')],
#                             '정치': [('정치', 'NNG')],
#                             '활동하는': [('활동', 'NNG'), ('하', 'XSV'), ('는', 'ETM')],
#                             '회원': [('회원', 'NNG')]},
#  'NWRW1800000040.301.6.5': {'19경기': [('19', 'SN'), ('경기', 'NNG')],
#                             '가도를': [('가도', 'NNG'), ('를', 'JKO')],
#                             '달리는': [('달리', 'VV'), ('는', 'ETM')],
#                             '담당했다.': [('담당', 'NNG'),
#                                       ('하', 'XSV'),
#                                       ('았', 'EP'),
#                                       ('다', 'EF'),
#                                       ('.', 'SF')],
#                             '데': [('데', 'NNB')],
#                             '몫을': [('몫', 'NNG'), ('을', 'JKO')],
#                             '무패(12승7무)': [('무패', 'NNG'),
#                                           ('(', 'SS'),
#                                           ('12', 'SN'),
#                                           ('승', 'NNB'),
#                                           ('7', 'SN'),
#                                           ('무', 'NNB'),
#                                           (')', 'SS')],
#                             '보탰고,': [('보태', 'VV'),
#                                      ('었', 'EP'),
#                                      ('고', 'EC'),
#                                      (',', 'SP')],
#                             '상위그룹에': [('상위', 'NNG'),
#                                       ('그룹', 'NNG'),
#                                       ('에', 'JKB')],
#                             '시즌에도': [('시즌', 'NNG'), ('에', 'JKB'), ('도', 'JX')],
#                             '연속': [('연속', 'NNG')],
#                             '올': [('올', 'NNG')],
#                             '인천이': [('인천', 'NNP'), ('이', 'JKS')],
#                             '진출하는데': [('진출', 'NNG'),
#                                       ('하', 'XSV'),
#                                       ('는데', 'EC')],
#                             '큰': [('크', 'VA'), ('ㄴ', 'ETM')],
#                             '힘을': [('힘', 'NNG'), ('을', 'JKO')]},
#  'NWRW1800000040.376.8.3': {'“이제': [('“', 'SS'), ('이제', 'MAG')],
#                             '결과를': [('결과', 'NNG'), ('를', 'JKO')],
#                             '기자들에게': [('기자', 'NNG'),
#                                       ('들', 'XSN'),
#                                       ('에게', 'JKB')],
#                             '끝난': [('끝나', 'VV'), ('ㄴ', 'ETM')],
#                             '답했다.': [('답', 'NNG'),
#                                      ('하', 'XSV'),
#                                      ('았', 'EP'),
#                                      ('다', 'EF'),
#                                      ('.', 'SF')],
#                             '뒤': [('뒤', 'NNG')],
#                             '막': [('막', 'MAG')],
#                             '묻는': [('묻', 'VV'), ('는', 'ETM')],
#                             '시작했다”고': [('시작', 'NNG'),
#                                        ('하', 'XSV'),
#                                        ('았', 'EP'),
#                                        ('다', 'EF'),
#                                        ('”', 'SS'),
#                                        ('고', 'JKQ')],
#                             '우': [('우', 'NNP')],
#                             '짤막하게': [('짤막하', 'VA'), ('게', 'EC')],
#                             '특별대표는': [('특별', 'NNG'),
#                                       ('대표', 'NNG'),
#                                       ('는', 'JX')],
#                             '회의가': [('회의', 'NNG'), ('가', 'JKS')]},
#  'NWRW1800000041.221.6.2': {'(조': [('(', 'SS'), ('조', 'NNP')],
#                             '1,': [('1', 'SN'), (',', 'SP')],
#                             '2심': [('2심', 'NNG')],
#                             '“(편지가': [('“', 'SS'),
#                                       ('(', 'SS'),
#                                       ('편지', 'NNG'),
#                                       ('가', 'JKS')],
#                             '것”이라고': [('것', 'NNB'),
#                                       ('”', 'SS'),
#                                       ('이라고', 'JKQ')],
#                             '것이라)': [('것', 'NNB'),
#                                      ('이', 'VCP'),
#                                      ('라', 'EC'),
#                                      (')', 'SS')],
#                             '된': [('되', 'VV'), ('ㄴ', 'ETM')],
#                             '마지못해': [('마지못하', 'VA'), ('아', 'EC')],
#                             '범행': [('범행', 'NNG')],
#                             '불과하고': [('불과', 'MAG'), ('하', 'XSA'), ('고', 'EC')],
#                             '사정에': [('사정', 'NNG'), ('에', 'JKB')],
#                             '상태에서': [('상태', 'NNG'), ('에서', 'JKB')],
#                             '성폭행': [('성폭행', 'NNG')],
#                             '쓰인': [('쓰이', 'VV'), ('ㄴ', 'ETM')],
#                             '씨를)': [('씨', 'NNB'), ('를', 'JKO'), (')', 'SS')],
#                             '이후': [('이후', 'NNG')],
#                             '임신까지': [('임신', 'NNG'), ('까지', 'JX')],
#                             '재판부는': [('재판부', 'NNG'), ('는', 'JX')],
#                             '지나': [('지나', 'VV'), ('아', 'EC')],
#                             '추종하게': [('추종', 'NNG'), ('하', 'XSV'), ('게', 'EC')],
#                             '판단했다.': [('판단', 'NNG'),
#                                       ('하', 'XSV'),
#                                       ('았', 'EP'),
#                                       ('다', 'EF'),
#                                       ('.', 'SF')],
#                             '피해자가': [('피해자', 'NNG'), ('가', 'JKS')],
#                             '한': [('하', 'VV'), ('ㄴ', 'ETM')],
#                             '한참': [('한참', 'MAG')],
#                             '후의': [('후', 'NNG'), ('의', 'JKG')]},
#  'NWRW1800000046.325.6.1': {"'긴급구호자금'": [("'", 'SS'),
#                                          ('긴급', 'NNG'),
#                                          ('구호', 'NNG'),
#                                          ('자금', 'NNG'),
#                                          ("'", 'SS')],
#                             '2013년까지': [('2013', 'SN'),
#                                         ('년', 'NNB'),
#                                         ('까지', 'JX')],
#                             '5000만원씩': [('5000', 'SN'),
#                                         ('만', 'NR'),
#                                         ('원', 'NNB'),
#                                         ('씩', 'XSN')],
#                             '고작': [('고작', 'MAG')],
#                             '대외비로': [('대외비', 'NNG'), ('로', 'JKB')],
#                             '돕기': [('돕', 'VV'), ('기', 'ETN')],
#                             '빠진': [('빠지', 'VV'), ('ㄴ', 'ETM')],
#                             '여성들을': [('여성', 'NNG'), ('들', 'XSN'), ('을', 'JKO')],
#                             '연': [('연', 'NNG')],
#                             '예산을': [('예산', 'NNG'), ('을', 'JKO')],
#                             '위한': [('위하', 'VV'), ('ㄴ', 'ETM')],
#                             '위험에': [('위험', 'NNG'), ('에', 'JKB')],
#                             '인신매매': [('인신매매', 'NNG')],
#                             '정부는': [('정부', 'NNG'), ('는', 'JX')],
#                             '집행했다.': [('집행', 'NNG'),
#                                       ('하', 'XSV'),
#                                       ('았', 'EP'),
#                                       ('다', 'EF'),
#                                       ('.', 'SF')],
#                             '책정,': [('책정', 'NNG'), (',', 'SP')],
#                             '탈북': [('탈북', 'NNG')]},
#  'NWRW1800000048.322.5.3': {'2경기': [('2', 'SN'), ('경기', 'NNG')],
#                             '8일': [('8', 'SN'), ('일', 'NNB')],
#                             '기록했다.': [('기록', 'NNG'),
#                                       ('하', 'XSV'),
#                                       ('았', 'EP'),
#                                       ('다', 'EF'),
#                                       ('.', 'SF')],
#                             '뒤': [('뒤', 'NNG')],
#                             '모습을': [('모습', 'NNG'), ('을', 'JKO')],
#                             '보였으나': [('보이', 'VV'), ('었', 'EP'), ('으나', 'EC')],
#                             '불안한': [('불안', 'NNG'), ('하', 'XSA'), ('ㄴ', 'ETM')],
#                             '성공한': [('성공', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM')],
#                             '안정을': [('안정', 'NNG'), ('을', 'JKO')],
#                             '엘지전': [('엘지전', 'NNG')],
#                             '역전에': [('역전', 'NNG'), ('에', 'JKB')],
#                             '연속': [('연속', 'NNG')],
#                             '유먼은': [('유먼', 'NNP'), ('은', 'JX')],
#                             '이후': [('이후', 'NNG')],
#                             '지난': [('지나', 'VV'), ('ㄴ', 'ETM')],
#                             '찾아': [('찾', 'VV'), ('아', 'EC')],
#                             '초반': [('초반', 'NNG')],
#                             '퀄리티스타트를': [('퀄리티스타트', 'NNG'), ('를', 'JKO')],
#                             '팀이': [('팀', 'NNG'), ('이', 'JKS')]},
#  'NWRW1800000049.344.6.2': {'‘코웨이': [('‘', 'SS'), ('코웨이', 'NNP')],
#                             '검사': [('검사', 'NNG')],
#                             '것으로': [('것', 'NNB'), ('으로', 'JKB')],
#                             '띄운': [('띄우', 'VV'), ('ㄴ', 'ETM')],
#                             '모으거나': [('모으', 'VV'), ('거나', 'EC')],
#                             '모임’': [('모임', 'NNG'), ('’', 'SS')],
#                             '밝히면': [('밝히', 'VV'), ('면', 'EC')],
#                             '사건을': [('사건', 'NNG'), ('을', 'JKO')],
#                             '손님을': [('손', 'NNG'), ('님', 'XSN'), ('을', 'JKO')],
#                             '알리는': [('알리', 'VV'), ('는', 'ETM')],
#                             '얼음정수기': [('얼음', 'NNG'), ('정수기', 'NNG')],
#                             '업체는': [('업체', 'NNG'), ('는', 'JX')],
#                             '일부': [('일부', 'NNG')],
#                             '있는': [('있', 'VX'), ('는', 'ETM')],
#                             '적용해주고': [('적용', 'NNG'),
#                                       ('하', 'XSV'),
#                                       ('아', 'EC'),
#                                       ('주', 'VX'),
#                                       ('고', 'EC')],
#                             '전해졌다.': [('전하', 'VV'),
#                                       ('아', 'EC'),
#                                       ('지', 'VX'),
#                                       ('었', 'EP'),
#                                       ('다', 'EF'),
#                                       ('.', 'SF')],
#                             '채': [('채', 'NNB')],
#                             '카페': [('카페', 'NNG')],
#                             '팝업창을': [('팝업', 'NNG'), ('창', 'NNG'), ('을', 'JKO')],
#                             '피해자': [('피해자', 'NNG')],
#                             '할인가를': [('할인', 'NNG'), ('가', 'XSN'), ('를', 'JKO')],
#                             '홈페이지에': [('홈페이지', 'NNG'), ('에', 'JKB')],
#                             '회원이라고': [('회원', 'NNG'),
#                                       ('이', 'VCP'),
#                                       ('라고', 'EC')]},
#  'NWRW1800000054.12.4.2': {'"러시아에서': [('"', 'SS'),
#                                       ('러시아', 'NNP'),
#                                       ('에서', 'JKB')],
#                            '"이': [('"', 'SS'), ('이', 'MMD')],
#                            '가족': [('가족', 'NNG')],
#                            '것"이라고': [('것', 'NNB'), ('"', 'SS'), ('이라고', 'JKQ')],
#                            '관계는': [('관계', 'NNG'), ('는', 'JX')],
#                            '권위로': [('권위', 'NNG'), ('로', 'JKB')],
#                            '뒷받침된다"며': [('뒷받침', 'NNG'),
#                                        ('되', 'XSV'),
#                                        ('ㄴ다', 'EF'),
#                                        ('"', 'SS'),
#                                        ('며', 'EC')],
#                            '말했다.': [('말', 'NNG'),
#                                     ('하', 'XSV'),
#                                     ('았', 'EP'),
#                                     ('다', 'EF'),
#                                     ('.', 'SF')],
#                            '미줄리나': [('미줄리나', 'NNP')],
#                            '법은': [('법', 'NNG'), ('은', 'JX')],
#                            '부모의': [('부모', 'NNG'), ('의', 'JKG')],
#                            '위한': [('위하', 'VV'), ('ㄴ', 'ETM')],
#                            '의원은': [('의원', 'NNG'), ('은', 'JX')],
#                            '이러한': [('이러하', 'VA'), ('ㄴ', 'ETM')],
#                            '전통문화를': [('전통문화', 'NNG'), ('를', 'JKO')],
#                            '지키기': [('지키', 'VV'), ('기', 'ETN')],
#                            '힘과': [('힘', 'NNG'), ('과', 'JC')]}}
# {'NWRW1800000022.411.3.1': {'3대': [('3', 'SN'), ('대', 'NNG')],
#   '경북': [('경북', 'NNP')],
#   '경주의': [('경주', 'NNP'), ('의', 'JKG')],
#   '고령의': [('고령', 'NNP'), ('의', 'JKG')],
#   '그가': [('그', 'NP'), ('가', 'JKS')],
#   '그린': [('그리', 'VV'), ('ㄴ', 'ETM')],
#   '대가야': [('대가야', 'NNP')],
#   '문화권인': [('문화', 'NNG'), ('권', 'XSN'), ('이', 'VCP'), ('ㄴ', 'ETM')],
#   '문화를': [('문화', 'NNG'), ('를', 'JKO')],
#   '불교문화,': [('불교문화', 'NNG'), (',', 'SP')],
#   '서정적인': [('서정', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('ㄴ', 'ETM')],
#   '선보인다.': [('선보이', 'VV'), ('ㄴ다', 'EF'), ('.', 'SF')],
#   '선비문화,': [('선비', 'NNG'), ('문화', 'NNG'), (',', 'SP')],
#   '안동의': [('안동', 'NNP'), ('의', 'JKG')],
#   '작품들을': [('작품', 'NNG'), ('들', 'XSN'), ('을', 'JKO')],
#   '풍경으로': [('풍경', 'NNG'), ('으로', 'JKB')]},
#  'NWRW1800000026.115.1.1': {'[6·2': [('[', 'SS'),
#    ('6', 'SN'),
#    ('·', 'SP'),
#    ('2', 'SN')],
#   '[충청]': [('[', 'SS'), ('충청', 'NNP'), (']', 'SS')],
#   '김기호씨': [('김기호', 'NNP'), ('씨', 'NNB')],
#   '보령시장': [('보령시장', 'NNG')],
#   '지금…]': [('지금', 'MAG'), ('…', 'SE'), (']', 'SS')],
#   '지방선거는': [('지방', 'NNG'), ('선거', 'NNG'), ('는', 'JX')],
#   '출마': [('출마', 'NNG')]},
#  'NWRW1800000033.329.6.1': {'것으로': [('것', 'NNB'), ('으로', 'JKB')],
#   '공군이': [('공군', 'NNG'), ('이', 'JKS')],
#   '군': [('군', 'NNG')],
#   '당국은': [('당국', 'NNG'), ('은', 'JX')],
#   '대비하고': [('대비', 'NNG'), ('하', 'XSV'), ('고', 'EC')],
#   '만일의': [('만일', 'NNG'), ('의', 'JKG')],
#   '맞아': [('맞', 'VV'), ('아', 'EC')],
#   '북한': [('북한', 'NNP')],
#   '분석하면서도': [('분석', 'NNG'), ('하', 'XSV'), ('면서', 'EC'), ('도', 'JX')],
#   '사태에': [('사태', 'NNG'), ('에', 'JKB')],
#   '있다.': [('있', 'VX'), ('다', 'EF'), ('.', 'SF')],
#   '전투검열기간을': [('전투', 'NNG'), ('검열', 'NNG'), ('기간', 'NNG'), ('을', 'JKO')],
#   '철저히': [('철저히', 'MAG')],
#   '최근': [('최근', 'MAG')],
#   '출격훈련을': [('출격', 'NNG'), ('훈련', 'NNG'), ('을', 'JKO')],
#   '하계': [('하계', 'NNG')],
#   '하는': [('하', 'VV'), ('는', 'ETM')],
#   '활발히': [('활발히', 'MAG')]},
#  'NWRW1800000036.398.5.2': {'“실제로': [('“', 'SS'), ('실제로', 'MAG')],
#   '가입': [('가입', 'NNG')],
#   '그를': [('그', 'NP'), ('를', 'JKO')],
#   '기억을': [('기억', 'NNG'), ('을', 'JKO')],
#   '다니는': [('다니', 'VV'), ('는', 'ETM')],
#   '당시': [('당시', 'NNG')],
#   '되는데,': [('되', 'VV'), ('는데', 'EC'), (',', 'SP')],
#   '되살렸다.': [('되살리', 'VV'), ('었', 'EP'), ('다', 'EF'), ('.', 'SF')],
#   '만난': [('만나', 'VV'), ('ㄴ', 'ETM')],
#   '많다고': [('많', 'VA'), ('다고', 'EC')],
#   '받아서': [('받', 'VV'), ('아서', 'EC')],
#   '브로커였다”고': [('브로커', 'NNG'),
#    ('이', 'VCP'),
#    ('었', 'EP'),
#    ('다', 'EF'),
#    ('”', 'SS'),
#    ('고', 'JKQ')],
#   '사람은': [('사람', 'NNG'), ('은', 'JX')],
#   '서명을': [('서명', 'NNG'), ('을', 'JKO')],
#   '수가': [('수', 'NNG'), ('가', 'JKS')],
#   '안': [('안', 'MAG')],
#   '엄청나게': [('엄청나', 'VA'), ('게', 'EC')],
#   '여기저기서': [('여기저기', 'NNG'), ('서', 'JKB')],
#   '열명도': [('열', 'NR'), ('명', 'NNB'), ('도', 'JX')],
#   '인사는': [('인사', 'NNG'), ('는', 'JX')],
#   '장사하고': [('장사', 'NNG'), ('하', 'XSV'), ('고', 'EC')],
#   '전형적인': [('전형', 'NNG'), ('적', 'XSN'), ('이', 'VCP'), ('ㄴ', 'ETM')],
#   '정치': [('정치', 'NNG')],
#   '활동하는': [('활동', 'NNG'), ('하', 'XSV'), ('는', 'ETM')],
#   '회원': [('회원', 'NNG')]},
#  'NWRW1800000040.301.6.5': {'19경기': [('19', 'SN'), ('경기', 'NNG')],
#   '가도를': [('가도', 'NNG'), ('를', 'JKO')],
#   '달리는': [('달리', 'VV'), ('는', 'ETM')],
#   '담당했다.': [('담당', 'NNG'),
#    ('하', 'XSV'),
#    ('았', 'EP'),
#    ('다', 'EF'),
#    ('.', 'SF')],
#   '데': [('데', 'NNB')],
#   '몫을': [('몫', 'NNG'), ('을', 'JKO')],
#   '무패(12승7무)': [('무패', 'NNG'),
#    ('(', 'SS'),
#    ('12', 'SN'),
#    ('승', 'NNB'),
#    ('7', 'SN'),
#    ('무', 'NNB'),
#    (')', 'SS')],
#   '보탰고,': [('보태', 'VV'), ('었', 'EP'), ('고', 'EC'), (',', 'SP')],
#   '상위그룹에': [('상위', 'NNG'), ('그룹', 'NNG'), ('에', 'JKB')],
#   '시즌에도': [('시즌', 'NNG'), ('에', 'JKB'), ('도', 'JX')],
#   '연속': [('연속', 'NNG')],
#   '올': [('올', 'NNG')],
#   '인천이': [('인천', 'NNP'), ('이', 'JKS')],
#   '진출하는데': [('진출', 'NNG'), ('하', 'XSV'), ('는데', 'EC')],
#   '큰': [('크', 'VA'), ('ㄴ', 'ETM')],
#   '힘을': [('힘', 'NNG'), ('을', 'JKO')]},
#  'NWRW1800000040.376.8.3': {'“이제': [('“', 'SS'), ('이제', 'MAG')],
#   '결과를': [('결과', 'NNG'), ('를', 'JKO')],
#   '기자들에게': [('기자', 'NNG'), ('들', 'XSN'), ('에게', 'JKB')],
#   '끝난': [('끝나', 'VV'), ('ㄴ', 'ETM')],
#   '답했다.': [('답', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF')],
#   '뒤': [('뒤', 'NNG')],
#   '막': [('막', 'MAG')],
#   '묻는': [('묻', 'VV'), ('는', 'ETM')],
#   '시작했다”고': [('시작', 'NNG'),
#    ('하', 'XSV'),
#    ('았', 'EP'),
#    ('다', 'EF'),
#    ('”', 'SS'),
#    ('고', 'JKQ')],
#   '우': [('우', 'NNP')],
#   '짤막하게': [('짤막하', 'VA'), ('게', 'EC')],
#   '특별대표는': [('특별', 'NNG'), ('대표', 'NNG'), ('는', 'JX')],
#   '회의가': [('회의', 'NNG'), ('가', 'JKS')]},
#  'NWRW1800000041.221.6.2': {'(조': [('(', 'SS'), ('조', 'NNP')],
#   '1,': [('1', 'SN'), (',', 'SP')],
#   '2심': [('2심', 'NNG')],
#   '“(편지가': [('“', 'SS'), ('(', 'SS'), ('편지', 'NNG'), ('가', 'JKS')],
#   '것”이라고': [('것', 'NNB'), ('”', 'SS'), ('이라고', 'JKQ')],
#   '것이라)': [('것', 'NNB'), ('이', 'VCP'), ('라', 'EC'), (')', 'SS')],
#   '된': [('되', 'VV'), ('ㄴ', 'ETM')],
#   '마지못해': [('마지못하', 'VA'), ('아', 'EC')],
#   '범행': [('범행', 'NNG')],
#   '불과하고': [('불과', 'MAG'), ('하', 'XSA'), ('고', 'EC')],
#   '사정에': [('사정', 'NNG'), ('에', 'JKB')],
#   '상태에서': [('상태', 'NNG'), ('에서', 'JKB')],
#   '성폭행': [('성폭행', 'NNG')],
#   '쓰인': [('쓰이', 'VV'), ('ㄴ', 'ETM')],
#   '씨를)': [('씨', 'NNB'), ('를', 'JKO'), (')', 'SS')],
#   '이후': [('이후', 'NNG')],
#   '임신까지': [('임신', 'NNG'), ('까지', 'JX')],
#   '재판부는': [('재판부', 'NNG'), ('는', 'JX')],
#   '지나': [('지나', 'VV'), ('아', 'EC')],
#   '추종하게': [('추종', 'NNG'), ('하', 'XSV'), ('게', 'EC')],
#   '판단했다.': [('판단', 'NNG'),
#    ('하', 'XSV'),
#    ('았', 'EP'),
#    ('다', 'EF'),
#    ('.', 'SF')],
#   '피해자가': [('피해자', 'NNG'), ('가', 'JKS')],
#   '한': [('하', 'VV'), ('ㄴ', 'ETM')],
#   '한참': [('한참', 'MAG')],
#   '후의': [('후', 'NNG'), ('의', 'JKG')]},
#  'NWRW1800000046.325.6.1': {"'긴급구호자금'": [("'", 'SS'),
#    ('긴급', 'NNG'),
#    ('구호', 'NNG'),
#    ('자금', 'NNG'),
#    ("'", 'SS')],
#   '2013년까지': [('2013', 'SN'), ('년', 'NNB'), ('까지', 'JX')],
#   '5000만원씩': [('5000', 'SN'), ('만', 'NR'), ('원', 'NNB'), ('씩', 'XSN')],
#   '고작': [('고작', 'MAG')],
#   '대외비로': [('대외비', 'NNG'), ('로', 'JKB')],
#   '돕기': [('돕', 'VV'), ('기', 'ETN')],
#   '빠진': [('빠지', 'VV'), ('ㄴ', 'ETM')],
#   '여성들을': [('여성', 'NNG'), ('들', 'XSN'), ('을', 'JKO')],
#   '연': [('연', 'NNG')],
#   '예산을': [('예산', 'NNG'), ('을', 'JKO')],
#   '위한': [('위하', 'VV'), ('ㄴ', 'ETM')],
#   '위험에': [('위험', 'NNG'), ('에', 'JKB')],
#   '인신매매': [('인신매매', 'NNG')],
#   '정부는': [('정부', 'NNG'), ('는', 'JX')],
#   '집행했다.': [('집행', 'NNG'),
#    ('하', 'XSV'),
#    ('았', 'EP'),
#    ('다', 'EF'),
#    ('.', 'SF')],
#   '책정,': [('책정', 'NNG'), (',', 'SP')],
#   '탈북': [('탈북', 'NNG')]},
#  'NWRW1800000048.322.5.3': {'2경기': [('2', 'SN'), ('경기', 'NNG')],
#   '8일': [('8', 'SN'), ('일', 'NNB')],
#   '기록했다.': [('기록', 'NNG'),
#    ('하', 'XSV'),
#    ('았', 'EP'),
#    ('다', 'EF'),
#    ('.', 'SF')],
#   '뒤': [('뒤', 'NNG')],
#   '모습을': [('모습', 'NNG'), ('을', 'JKO')],
#   '보였으나': [('보이', 'VV'), ('었', 'EP'), ('으나', 'EC')],
#   '불안한': [('불안', 'NNG'), ('하', 'XSA'), ('ㄴ', 'ETM')],
#   '성공한': [('성공', 'NNG'), ('하', 'XSV'), ('ㄴ', 'ETM')],
#   '안정을': [('안정', 'NNG'), ('을', 'JKO')],
#   '엘지전': [('엘지전', 'NNG')],
#   '역전에': [('역전', 'NNG'), ('에', 'JKB')],
#   '연속': [('연속', 'NNG')],
#   '유먼은': [('유먼', 'NNP'), ('은', 'JX')],
#   '이후': [('이후', 'NNG')],
#   '지난': [('지나', 'VV'), ('ㄴ', 'ETM')],
#   '찾아': [('찾', 'VV'), ('아', 'EC')],
#   '초반': [('초반', 'NNG')],
#   '퀄리티스타트를': [('퀄리티스타트', 'NNG'), ('를', 'JKO')],
#   '팀이': [('팀', 'NNG'), ('이', 'JKS')]},
#  'NWRW1800000049.344.6.2': {'‘코웨이': [('‘', 'SS'), ('코웨이', 'NNP')],
#   '검사': [('검사', 'NNG')],
#   '것으로': [('것', 'NNB'), ('으로', 'JKB')],
#   '띄운': [('띄우', 'VV'), ('ㄴ', 'ETM')],
#   '모으거나': [('모으', 'VV'), ('거나', 'EC')],
#   '모임’': [('모임', 'NNG'), ('’', 'SS')],
#   '밝히면': [('밝히', 'VV'), ('면', 'EC')],
#   '사건을': [('사건', 'NNG'), ('을', 'JKO')],
#   '손님을': [('손', 'NNG'), ('님', 'XSN'), ('을', 'JKO')],
#   '알리는': [('알리', 'VV'), ('는', 'ETM')],
#   '얼음정수기': [('얼음', 'NNG'), ('정수기', 'NNG')],
#   '업체는': [('업체', 'NNG'), ('는', 'JX')],
#   '일부': [('일부', 'NNG')],
#   '있는': [('있', 'VX'), ('는', 'ETM')],
#   '적용해주고': [('적용', 'NNG'),
#    ('하', 'XSV'),
#    ('아', 'EC'),
#    ('주', 'VX'),
#    ('고', 'EC')],
#   '전해졌다.': [('전하', 'VV'),
#    ('아', 'EC'),
#    ('지', 'VX'),
#    ('었', 'EP'),
#    ('다', 'EF'),
#    ('.', 'SF')],
#   '채': [('채', 'NNB')],
#   '카페': [('카페', 'NNG')],
#   '팝업창을': [('팝업', 'NNG'), ('창', 'NNG'), ('을', 'JKO')],
#   '피해자': [('피해자', 'NNG')],
#   '할인가를': [('할인', 'NNG'), ('가', 'XSN'), ('를', 'JKO')],
#   '홈페이지에': [('홈페이지', 'NNG'), ('에', 'JKB')],
#   '회원이라고': [('회원', 'NNG'), ('이', 'VCP'), ('라고', 'EC')]},
#  'NWRW1800000054.12.4.2': {'"러시아에서': [('"', 'SS'),
#    ('러시아', 'NNP'),
#    ('에서', 'JKB')],
#   '"이': [('"', 'SS'), ('이', 'MMD')],
#   '가족': [('가족', 'NNG')],
#   '것"이라고': [('것', 'NNB'), ('"', 'SS'), ('이라고', 'JKQ')],
#   '관계는': [('관계', 'NNG'), ('는', 'JX')],
#   '권위로': [('권위', 'NNG'), ('로', 'JKB')],
#   '뒷받침된다"며': [('뒷받침', 'NNG'),
#    ('되', 'XSV'),
#    ('ㄴ다', 'EF'),
#    ('"', 'SS'),
#    ('며', 'EC')],
#   '말했다.': [('말', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('다', 'EF'), ('.', 'SF')],
#   '미줄리나': [('미줄리나', 'NNP')],
#   '법은': [('법', 'NNG'), ('은', 'JX')],
#   '부모의': [('부모', 'NNG'), ('의', 'JKG')],
#   '위한': [('위하', 'VV'), ('ㄴ', 'ETM')],
#   '의원은': [('의원', 'NNG'), ('은', 'JX')],
#   '이러한': [('이러하', 'VA'), ('ㄴ', 'ETM')],
#   '전통문화를': [('전통문화', 'NNG'), ('를', 'JKO')],
#   '지키기': [('지키', 'VV'), ('기', 'ETN')],
#   '힘과': [('힘', 'NNG'), ('과', 'JC')]}}

# %%
x = df[df['sentence_id'] == 'NWRW1800000041.221.6.2']
#x[x['word_id'] == 1]
print(x['sentence'].iloc[0])
x
# Out:
# 1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정에 불과하고 피해자가 임신까지 한 상태에서 마지못해 (조 씨를) 추종하게 된 것”이라고 판단했다.
#                     doc_id             sentence_id  \
# 354227  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354228  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354229  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354230  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354231  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354232  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354233  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354234  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354235  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354236  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354237  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354238  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354239  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354240  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354241  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354242  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354243  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354244  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354245  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354246  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354247  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354248  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354249  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354250  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354251  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354252  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354253  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354254  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354255  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354256  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354257  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354258  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354259  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354260  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354261  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354262  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354263  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354264  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354265  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354266  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354267  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354268  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354269  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354270  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354271  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354272  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354273  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354274  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354275  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354276  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354277  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354278  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354279  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354280  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354281  NWRW1800000041.221  NWRW1800000041.221.6.2
# 354282  NWRW1800000041.221  NWRW1800000041.221.6.2
#
#                                                  sentence  id  form label  \
# 354227  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   1     1    SN
# 354228  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   2     ,    SP
# 354229  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   3    2심   NNG
# 354230  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   4   재판부   NNG
# 354231  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   5     는    JX
# 354232  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   6     “    SS
# 354233  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   7     (    SS
# 354234  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   8    편지   NNG
# 354235  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...   9     가   JKS
# 354236  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  10   성폭행   NNG
# 354237  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  11    이후   NNG
# 354238  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  12    한참   MAG
# 354239  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  13    지나    VV
# 354240  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  14     아    EC
# 354241  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  15    쓰이    VV
# 354242  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  16     ㄴ   ETM
# 354243  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  17     것   NNB
# 354244  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  18     이   VCP
# 354245  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  19     라    EC
# 354246  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  20     )    SS
# 354247  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  21    범행   NNG
# 354248  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  22     후   NNG
# 354249  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  23     의   JKG
# 354250  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  24    사정   NNG
# 354251  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  25     에   JKB
# 354252  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  26    불과   MAG
# 354253  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  27     하   XSA
# 354254  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  28     고    EC
# 354255  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  29   피해자   NNG
# 354256  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  30     가   JKS
# 354257  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  31    임신   NNG
# 354258  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  32    까지    JX
# 354259  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  33     하    VV
# 354260  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  34     ㄴ   ETM
# 354261  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  35    상태   NNG
# 354262  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  36    에서   JKB
# 354263  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  37  마지못하    VA
# 354264  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  38     아    EC
# 354265  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  39     (    SS
# 354266  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  40     조   NNP
# 354267  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  41     씨   NNB
# 354268  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  42     를   JKO
# 354269  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  43     )    SS
# 354270  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  44    추종   NNG
# 354271  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  45     하   XSV
# 354272  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  46     게    EC
# 354273  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  47     되    VV
# 354274  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  48     ㄴ   ETM
# 354275  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  49     것   NNB
# 354276  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  50     ”    SS
# 354277  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  51   이라고   JKQ
# 354278  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  52    판단   NNG
# 354279  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  53     하   XSV
# 354280  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  54     았    EP
# 354281  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  55     다    EF
# 354282  1, 2심 재판부는 “(편지가 성폭행 이후 한참 지나 쓰인 것이라) 범행 후의 사정...  56     .    SF
#
#         word_id  position
# 354227        1         1
# 354228        1         2
# 354229        2         1
# 354230        3         1
# 354231        3         2
# 354232        4         1
# 354233        4         2
# 354234        4         3
# 354235        4         4
# 354236        5         1
# 354237        6         1
# 354238        7         1
# 354239        8         1
# 354240        8         2
# 354241        9         1
# 354242        9         2
# 354243       10         1
# 354244       10         2
# 354245       10         3
# 354246       10         4
# 354247       11         1
# 354248       12         1
# 354249       12         2
# 354250       13         1
# 354251       13         2
# 354252       14         1
# 354253       14         2
# 354254       14         3
# 354255       15         1
# 354256       15         2
# 354257       16         1
# 354258       16         2
# 354259       17         1
# 354260       17         2
# 354261       18         1
# 354262       18         2
# 354263       19         1
# 354264       19         2
# 354265       20         1
# 354266       20         2
# 354267       21         1
# 354268       21         2
# 354269       21         3
# 354270       22         1
# 354271       22         2
# 354272       22         3
# 354273       23         1
# 354274       23         2
# 354275       24         1
# 354276       24         2
# 354277       24         3
# 354278       25         1
# 354279       25         2
# 354280       25         3
# 354281       25         4
# 354282       25         5

# %%
with open("sentence_to_morpheme.txt", "a") as morpheme_file:
    sentence_pos = 0
    word_pos = 0
    
    times = 0
    for id in sentence_id_list:
        morpheme_file.write("@@\n")
        sub_df = df[df['sentence_id']==id]
        sentence = sub_df.reset_index().iloc[0]['sentence']
        splitted_sentence = sentence.split(" ")
        idx = 0
        word_id = 1
        word_id_set = set(sub_df['word_id'].to_list())
        
        for word_id in word_id_set:
            temp = sub_df
            if sentence[sentence_pos] == " ":
                sentence_pos += 1
                continue
            else:
                for word_pos in range(len(splitted_sentence[word_id] - 1)):
                
        
        for word_id in word_id_set:
            temp = sub_df[sub_df['word_id'] == word_id]
            word = ""
            label = ""
            for i in range(len(temp)):
                for s in temp.iloc[i]['form']:
                    word += s
                    label += temp.iloc[i]['label'] + " "
            morpheme_file.write(f"{word}    {label}\n")
            word_id += 1
        times += 1
        if times % 10 == 0:
            break
            
    morpheme_file.write('@@')

# %%
'''
@@
word (form + form + ...)    label label label ...
⁝
@@
'''

with open("sentence_to_morpheme.txt", "a") as morpheme_file:
    times = 0
    for id in sentence_id_list:
        morpheme_file.write("@@\n")
        sub_df = df[df['sentence_id']==id]
        sentence = sub_df.reset_index().iloc[0]['sentence']
        splitted_sentence = sentence.split(" ")
        idx = 0
        word_id = 1
        word_id_set = set(sub_df['word_id'].to_list())
        print(sentence)
        
        for word_id in word_id_set:
            temp = sub_df[sub_df['word_id'] == word_id]
            word = ""
            label = ""
            for i in range(len(temp)):
                for s in temp.iloc[i]['form']:
                    word += s
                    label += temp.iloc[i]['label'] + " "
            morpheme_file.write(f"{word}    {label}\n")
            word_id += 1
        times += 1
        if times % 10 == 0:
            break
            
    morpheme_file.write('@@')
# Out:
# 장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조례 개정을 추진하고 있다.
#                doc_id             sentence_id  \
# 0  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                             sentence  id form label  word_id  \
# 0  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...   6   관장   NNG        4
#
#    position
# 0         1
#                doc_id             sentence_id  \
# 1  NWRW1800000044.248  NWRW1800000044.248.7.1
# 2  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                             sentence  id form label  word_id  \
# 1  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...   7   자리   NNG        5
# 2  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...   8    를   JKO        5
#
#    position
# 1         1
# 2         2
#                doc_id             sentence_id  \
# 3  NWRW1800000044.248  NWRW1800000044.248.7.1
# 4  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                             sentence  id form label  word_id  \
# 3  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...   9   없애    VV        6
# 4  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  10    고    EC        6
#
#    position
# 3         1
# 4         2
#                doc_id             sentence_id  \
# 5  NWRW1800000044.248  NWRW1800000044.248.7.1
# 6  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                             sentence  id form label  word_id  \
# 5  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  11   구청   NNG        7
# 6  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  12    이   JKS        7
#
#    position
# 5         1
# 6         2
#                doc_id             sentence_id  \
# 7  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                             sentence  id form label  word_id  \
# 7  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  13   직접   MAG        8
#
#    position
# 7         1
#                 doc_id             sentence_id  \
# 8   NWRW1800000044.248  NWRW1800000044.248.7.1
# 9   NWRW1800000044.248  NWRW1800000044.248.7.1
# 10  NWRW1800000044.248  NWRW1800000044.248.7.1
# 11  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                              sentence  id form label  word_id  \
# 8   장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  14   관리   NNG        9
# 9   장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  15    하   XSV        9
# 10  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  16    겠    EP        9
# 11  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  17   다며    EC        9
#
#     position
# 8          1
# 9          2
# 10         3
# 11         4
#                 doc_id             sentence_id  \
# 12  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                              sentence  id form label  word_id  \
# 12  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  18   조례   NNG       10
#
#     position
# 12         1
#                 doc_id             sentence_id  \
# 13  NWRW1800000044.248  NWRW1800000044.248.7.1
# 14  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                              sentence  id form label  word_id  \
# 13  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  19   개정   NNG       11
# 14  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  20    을   JKO       11
#
#     position
# 13         1
# 14         2
#                 doc_id             sentence_id  \
# 15  NWRW1800000044.248  NWRW1800000044.248.7.1
# 16  NWRW1800000044.248  NWRW1800000044.248.7.1
# 17  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                              sentence  id form label  word_id  \
# 15  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  21   추진   NNG       12
# 16  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  22    하   XSV       12
# 17  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  23    고    EC       12
#
#     position
# 15         1
# 16         2
# 17         3
#                 doc_id             sentence_id  \
# 18  NWRW1800000044.248  NWRW1800000044.248.7.1
# 19  NWRW1800000044.248  NWRW1800000044.248.7.1
# 20  NWRW1800000044.248  NWRW1800000044.248.7.1
#
#                                              sentence  id form label  word_id  \
# 18  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  24    있    VX       13
# 19  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  25    다    EF       13
# 20  장석현 남동구청장은 남동소래아트홀의 관장 자리를 없애고 구청이 직접 관리하겠다며 조...  26    .    SF       13
#
#     position
# 18         1
# 19         2
# 20         3
# 이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들을 위해 200억원 넘게 들여 신축 기증한 것으로, 그동안 전문 예술인이 관장을 맡아 운영해왔다.
#                 doc_id             sentence_id  \
# 21  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 21  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   1    이   MMD        1
#
#     position
# 21         1
#                 doc_id             sentence_id  \
# 22  NWRW1800000044.248  NWRW1800000044.248.7.2
# 23  NWRW1800000044.248  NWRW1800000044.248.7.2
# 24  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 22  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   2   아트   NNG        2
# 23  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   3    홀   NNG        2
# 24  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   4    은    JX        2
#
#     position
# 22         1
# 23         2
# 24         3
#                 doc_id             sentence_id  \
# 25  NWRW1800000044.248  NWRW1800000044.248.7.2
# 26  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id  form label  \
# 25  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   5  한화건설   NNP
# 26  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   6     이   JKS
#
#     word_id  position
# 25        3         1
# 26        3         2
#                 doc_id             sentence_id  \
# 27  NWRW1800000044.248  NWRW1800000044.248.7.2
# 28  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id  form label  \
# 27  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   7  2011    SN
# 28  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   8     년   NNB
#
#     word_id  position
# 27        4         1
# 28        4         2
#                 doc_id             sentence_id  \
# 29  NWRW1800000044.248  NWRW1800000044.248.7.2
# 30  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 29  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...   9    대   XPN        5
# 30  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  10   규모   NNG        5
#
#     position
# 29         1
# 30         2
#                 doc_id             sentence_id  \
# 31  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 31  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  11  아파트   NNG        6
#
#     position
# 31         1
#                 doc_id             sentence_id  \
# 32  NWRW1800000044.248  NWRW1800000044.248.7.2
# 33  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 32  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  12   단지   NNG        7
# 33  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  13    를   JKO        7
#
#     position
# 32         1
# 33         2
#                 doc_id             sentence_id  \
# 34  NWRW1800000044.248  NWRW1800000044.248.7.2
# 35  NWRW1800000044.248  NWRW1800000044.248.7.2
# 36  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 34  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  14   조성   NNG        8
# 35  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  15    하   XSV        8
# 36  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  16   면서    EC        8
#
#     position
# 34         1
# 35         2
# 36         3
#                 doc_id             sentence_id  \
# 37  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 37  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  17   주변   NNG        9
#
#     position
# 37         1
#                 doc_id             sentence_id  \
# 38  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 38  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  18   지역   NNG       10
#
#     position
# 38         1
#                 doc_id             sentence_id  \
# 39  NWRW1800000044.248  NWRW1800000044.248.7.2
# 40  NWRW1800000044.248  NWRW1800000044.248.7.2
# 41  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 39  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  19   주민   NNG       11
# 40  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  20    들   XSN       11
# 41  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  21    을   JKO       11
#
#     position
# 39         1
# 40         2
# 41         3
#                 doc_id             sentence_id  \
# 42  NWRW1800000044.248  NWRW1800000044.248.7.2
# 43  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 42  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  22   위하    VV       12
# 43  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  23    아    EC       12
#
#     position
# 42         1
# 43         2
#                 doc_id             sentence_id  \
# 44  NWRW1800000044.248  NWRW1800000044.248.7.2
# 45  NWRW1800000044.248  NWRW1800000044.248.7.2
# 46  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 44  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  24  200    SN       13
# 45  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  25    억    NR       13
# 46  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  26    원   NNB       13
#
#     position
# 44         1
# 45         2
# 46         3
#                 doc_id             sentence_id  \
# 47  NWRW1800000044.248  NWRW1800000044.248.7.2
# 48  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 47  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  27    넘    VV       14
# 48  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  28    게    EC       14
#
#     position
# 47         1
# 48         2
#                 doc_id             sentence_id  \
# 49  NWRW1800000044.248  NWRW1800000044.248.7.2
# 50  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 49  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  29   들이    VV       15
# 50  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  30    어    EC       15
#
#     position
# 49         1
# 50         2
#                 doc_id             sentence_id  \
# 51  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 51  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  31   신축   NNG       16
#
#     position
# 51         1
#                 doc_id             sentence_id  \
# 52  NWRW1800000044.248  NWRW1800000044.248.7.2
# 53  NWRW1800000044.248  NWRW1800000044.248.7.2
# 54  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 52  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  32   기증   NNG       17
# 53  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  33    하   XSV       17
# 54  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  34    ㄴ   ETM       17
#
#     position
# 52         1
# 53         2
# 54         3
#                 doc_id             sentence_id  \
# 55  NWRW1800000044.248  NWRW1800000044.248.7.2
# 56  NWRW1800000044.248  NWRW1800000044.248.7.2
# 57  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 55  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  35    것   NNB       18
# 56  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  36   으로   JKB       18
# 57  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  37    ,    SP       18
#
#     position
# 55         1
# 56         2
# 57         3
#                 doc_id             sentence_id  \
# 58  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 58  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  38  그동안   NNG       19
#
#     position
# 58         1
#                 doc_id             sentence_id  \
# 59  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 59  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  39   전문   NNG       20
#
#     position
# 59         1
#                 doc_id             sentence_id  \
# 60  NWRW1800000044.248  NWRW1800000044.248.7.2
# 61  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 60  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  40  예술인   NNG       21
# 61  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  41    이   JKS       21
#
#     position
# 60         1
# 61         2
#                 doc_id             sentence_id  \
# 62  NWRW1800000044.248  NWRW1800000044.248.7.2
# 63  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 62  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  42   관장   NNG       22
# 63  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  43    을   JKO       22
#
#     position
# 62         1
# 63         2
#                 doc_id             sentence_id  \
# 64  NWRW1800000044.248  NWRW1800000044.248.7.2
# 65  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 64  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  44    맡    VV       23
# 65  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  45    아    EC       23
#
#     position
# 64         1
# 65         2
#                 doc_id             sentence_id  \
# 66  NWRW1800000044.248  NWRW1800000044.248.7.2
# 67  NWRW1800000044.248  NWRW1800000044.248.7.2
# 68  NWRW1800000044.248  NWRW1800000044.248.7.2
# 69  NWRW1800000044.248  NWRW1800000044.248.7.2
# 70  NWRW1800000044.248  NWRW1800000044.248.7.2
# 71  NWRW1800000044.248  NWRW1800000044.248.7.2
# 72  NWRW1800000044.248  NWRW1800000044.248.7.2
#
#                                              sentence  id form label  word_id  \
# 66  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  46   운영   NNG       24
# 67  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  47    하   XSV       24
# 68  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  48    아    EC       24
# 69  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  49    오    VX       24
# 70  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  50    았    EP       24
# 71  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  51    다    EF       24
# 72  이 아트홀은 한화건설이 2011년 대규모 아파트 단지를 조성하면서 주변 지역 주민들...  52    .    SF       24
#
#     position
# 66         1
# 67         2
# 68         3
# 69         4
# 70         5
# 71         6
# 72         7
# 주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인데 구청이 직접 관리하겠다는 것은 지역 주민들을 무시하는 것이며, 박근혜 대통령의 핵심 정책인 ‘문화융성정책’에도 역행한다”며 반발하고 있다.
#                 doc_id             sentence_id  \
# 73  NWRW1800000044.248  NWRW1800000044.248.8.1
# 74  NWRW1800000044.248  NWRW1800000044.248.8.1
# 75  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 73  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   1   주민   NNG        1
# 74  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   2    들   XSN        1
# 75  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   3    과    JC        1
#
#     position
# 73         1
# 74         2
# 75         3
#                 doc_id             sentence_id  \
# 76  NWRW1800000044.248  NWRW1800000044.248.8.1
# 77  NWRW1800000044.248  NWRW1800000044.248.8.1
# 78  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 76  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   4  예술인   NNG        2
# 77  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   5    들   XSN        2
# 78  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   6    은    JX        2
#
#     position
# 76         1
# 77         2
# 78         3
#                 doc_id             sentence_id  \
# 79  NWRW1800000044.248  NWRW1800000044.248.8.1
# 80  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 79  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   7    “    SS        3
# 80  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   8  아파트   NNG        3
#
#     position
# 79         1
# 80         2
#                 doc_id             sentence_id  \
# 81  NWRW1800000044.248  NWRW1800000044.248.8.1
# 82  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 81  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...   9   사업   NNG        4
# 82  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  10   승인   NNG        4
#
#     position
# 81         1
# 82         2
#                 doc_id             sentence_id  \
# 83  NWRW1800000044.248  NWRW1800000044.248.8.1
# 84  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 83  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  11   조건   NNG        5
# 84  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  12   으로   JKB        5
#
#     position
# 83         1
# 84         2
#                 doc_id             sentence_id  \
# 85  NWRW1800000044.248  NWRW1800000044.248.8.1
# 86  NWRW1800000044.248  NWRW1800000044.248.8.1
# 87  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 85  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  13   아트   NNG        6
# 86  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  14    홀   NNG        6
# 87  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  15    을   JKO        6
#
#     position
# 85         1
# 86         2
# 87         3
#                 doc_id             sentence_id  \
# 88  NWRW1800000044.248  NWRW1800000044.248.8.1
# 89  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 88  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  16    짓    VV        7
# 89  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  17    어    EC        7
#
#     position
# 88         1
# 89         2
#                 doc_id             sentence_id  \
# 90  NWRW1800000044.248  NWRW1800000044.248.8.1
# 91  NWRW1800000044.248  NWRW1800000044.248.8.1
# 92  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 90  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  18   주민   NNG        8
# 91  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  19    들   XSN        8
# 92  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  20   에게   JKB        8
#
#     position
# 90         1
# 91         2
# 92         3
#                 doc_id             sentence_id  \
# 93  NWRW1800000044.248  NWRW1800000044.248.8.1
# 94  NWRW1800000044.248  NWRW1800000044.248.8.1
# 95  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 93  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  21   기증   NNG        9
# 94  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  22    하   XSV        9
# 95  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  23    ㄴ   ETM        9
#
#     position
# 93         1
# 94         2
# 95         3
#                 doc_id             sentence_id  \
# 96  NWRW1800000044.248  NWRW1800000044.248.8.1
# 97  NWRW1800000044.248  NWRW1800000044.248.8.1
# 98  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                              sentence  id form label  word_id  \
# 96  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  24    것   NNB       10
# 97  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  25    이   VCP       10
# 98  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  26   ㄴ데    EC       10
#
#     position
# 96         1
# 97         2
# 98         3
#                  doc_id             sentence_id  \
# 99   NWRW1800000044.248  NWRW1800000044.248.8.1
# 100  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 99   주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  27   구청   NNG
# 100  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  28    이   JKS
#
#      word_id  position
# 99        11         1
# 100       11         2
#                  doc_id             sentence_id  \
# 101  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 101  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  29   직접   MAG
#
#      word_id  position
# 101       12         1
#                  doc_id             sentence_id  \
# 102  NWRW1800000044.248  NWRW1800000044.248.8.1
# 103  NWRW1800000044.248  NWRW1800000044.248.8.1
# 104  NWRW1800000044.248  NWRW1800000044.248.8.1
# 105  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 102  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  30   관리   NNG
# 103  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  31    하   XSV
# 104  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  32    겠    EP
# 105  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  33   다는   ETM
#
#      word_id  position
# 102       13         1
# 103       13         2
# 104       13         3
# 105       13         4
#                  doc_id             sentence_id  \
# 106  NWRW1800000044.248  NWRW1800000044.248.8.1
# 107  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 106  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  34    것   NNB
# 107  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  35    은    JX
#
#      word_id  position
# 106       14         1
# 107       14         2
#                  doc_id             sentence_id  \
# 108  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 108  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  36   지역   NNG
#
#      word_id  position
# 108       15         1
#                  doc_id             sentence_id  \
# 109  NWRW1800000044.248  NWRW1800000044.248.8.1
# 110  NWRW1800000044.248  NWRW1800000044.248.8.1
# 111  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 109  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  37   주민   NNG
# 110  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  38    들   XSN
# 111  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  39    을   JKO
#
#      word_id  position
# 109       16         1
# 110       16         2
# 111       16         3
#                  doc_id             sentence_id  \
# 112  NWRW1800000044.248  NWRW1800000044.248.8.1
# 113  NWRW1800000044.248  NWRW1800000044.248.8.1
# 114  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 112  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  40   무시   NNG
# 113  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  41    하   XSV
# 114  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  42    는   ETM
#
#      word_id  position
# 112       17         1
# 113       17         2
# 114       17         3
#                  doc_id             sentence_id  \
# 115  NWRW1800000044.248  NWRW1800000044.248.8.1
# 116  NWRW1800000044.248  NWRW1800000044.248.8.1
# 117  NWRW1800000044.248  NWRW1800000044.248.8.1
# 118  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 115  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  43    것   NNB
# 116  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  44    이   VCP
# 117  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  45    며    EC
# 118  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  46    ,    SP
#
#      word_id  position
# 115       18         1
# 116       18         2
# 117       18         3
# 118       18         4
#                  doc_id             sentence_id  \
# 119  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 119  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  47  박근혜   NNP
#
#      word_id  position
# 119       19         1
#                  doc_id             sentence_id  \
# 120  NWRW1800000044.248  NWRW1800000044.248.8.1
# 121  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 120  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  48  대통령   NNG
# 121  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  49    의   JKG
#
#      word_id  position
# 120       20         1
# 121       20         2
#                  doc_id             sentence_id  \
# 122  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 122  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  50   핵심   NNG
#
#      word_id  position
# 122       21         1
#                  doc_id             sentence_id  \
# 123  NWRW1800000044.248  NWRW1800000044.248.8.1
# 124  NWRW1800000044.248  NWRW1800000044.248.8.1
# 125  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 123  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  51   정책   NNG
# 124  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  52    이   VCP
# 125  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  53    ㄴ   ETM
#
#      word_id  position
# 123       22         1
# 124       22         2
# 125       22         3
#                  doc_id             sentence_id  \
# 126  NWRW1800000044.248  NWRW1800000044.248.8.1
# 127  NWRW1800000044.248  NWRW1800000044.248.8.1
# 128  NWRW1800000044.248  NWRW1800000044.248.8.1
# 129  NWRW1800000044.248  NWRW1800000044.248.8.1
# 130  NWRW1800000044.248  NWRW1800000044.248.8.1
# 131  NWRW1800000044.248  NWRW1800000044.248.8.1
# 132  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 126  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  54    ‘    SS
# 127  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  55   문화   NNG
# 128  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  56   융성   NNG
# 129  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  57   정책   NNG
# 130  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  58    ’    SS
# 131  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  59    에   JKB
# 132  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  60    도    JX
#
#      word_id  position
# 126       23         1
# 127       23         2
# 128       23         3
# 129       23         4
# 130       23         5
# 131       23         6
# 132       23         7
#                  doc_id             sentence_id  \
# 133  NWRW1800000044.248  NWRW1800000044.248.8.1
# 134  NWRW1800000044.248  NWRW1800000044.248.8.1
# 135  NWRW1800000044.248  NWRW1800000044.248.8.1
# 136  NWRW1800000044.248  NWRW1800000044.248.8.1
# 137  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 133  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  61   역행   NNG
# 134  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  62    하   XSV
# 135  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  63   ㄴ다    EF
# 136  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  64    ”    SS
# 137  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  65    며    EC
#
#      word_id  position
# 133       24         1
# 134       24         2
# 135       24         3
# 136       24         4
# 137       24         5
#                  doc_id             sentence_id  \
# 138  NWRW1800000044.248  NWRW1800000044.248.8.1
# 139  NWRW1800000044.248  NWRW1800000044.248.8.1
# 140  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 138  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  66   반발   NNG
# 139  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  67    하   XSV
# 140  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  68    고    EC
#
#      word_id  position
# 138       25         1
# 139       25         2
# 140       25         3
#                  doc_id             sentence_id  \
# 141  NWRW1800000044.248  NWRW1800000044.248.8.1
# 142  NWRW1800000044.248  NWRW1800000044.248.8.1
# 143  NWRW1800000044.248  NWRW1800000044.248.8.1
#
#                                               sentence  id form label  \
# 141  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  69    있    VX
# 142  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  70    다    EF
# 143  주민들과 예술인들은 “아파트 사업승인 조건으로 아트홀을 지어 주민들에게 기증한 것인...  71    .    SF
#
#      word_id  position
# 141       26         1
# 142       26         2
# 143       26         3
# 남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.
#                  doc_id             sentence_id  \
# 144  NWRW1800000044.248  NWRW1800000044.248.8.2
# 145  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 144  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   1  남동구   NNP        1         1
# 145  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   2    가   JKS        1         2
#                  doc_id             sentence_id  \
# 146  NWRW1800000044.248  NWRW1800000044.248.8.2
# 147  NWRW1800000044.248  NWRW1800000044.248.8.2
# 148  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 146  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   3   발의   NNG        2         1
# 147  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   4    하   XSV        2         2
# 148  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   5    ㄴ   ETM        2         3
#                  doc_id             sentence_id  \
# 149  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 149  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   6   관련   NNG        3         1
#                  doc_id             sentence_id  \
# 150  NWRW1800000044.248  NWRW1800000044.248.8.2
# 151  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 150  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   7   조례   NNG        4         1
# 151  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   8    는    JX        4         2
#                  doc_id             sentence_id  \
# 152  NWRW1800000044.248  NWRW1800000044.248.8.2
# 153  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 152  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.   9   18    SN        5         1
# 153  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  10    일   NNB        5         2
#                  doc_id             sentence_id  \
# 154  NWRW1800000044.248  NWRW1800000044.248.8.2
# 155  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 154  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  11    구   NNG        6         1
# 155  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  12   의회   NNG        6         2
#                  doc_id             sentence_id  \
# 156  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 156  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  13  본회의   NNG        7         1
#                  doc_id             sentence_id  \
# 157  NWRW1800000044.248  NWRW1800000044.248.8.2
# 158  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 157  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  14   통과   NNG        8         1
# 158  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  15    를   JKO        8         2
#                  doc_id             sentence_id  \
# 159  NWRW1800000044.248  NWRW1800000044.248.8.2
# 160  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 159  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  16   앞두    VV        9         1
# 160  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  17    고    EC        9         2
#                  doc_id             sentence_id  \
# 161  NWRW1800000044.248  NWRW1800000044.248.8.2
# 162  NWRW1800000044.248  NWRW1800000044.248.8.2
# 163  NWRW1800000044.248  NWRW1800000044.248.8.2
#
#                                     sentence  id form label  word_id  position
# 161  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  18    있    VX       10         1
# 162  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  19    다    EF       10         2
# 163  남동구가 발의한 관련 조례는 18일 구의회 본회의 통과를 앞두고 있다.  20    .    SF       10         3
# 남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.
#                  doc_id             sentence_id  \
# 164  NWRW1800000044.248  NWRW1800000044.248.9.1
# 165  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 164  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   1  남동구   NNP        1         1
# 165  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   2    는    JX        1         2
#                  doc_id             sentence_id  \
# 166  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 166  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   3    또   MAG        2         1
#                  doc_id             sentence_id  \
# 167  NWRW1800000044.248  NWRW1800000044.248.9.1
# 168  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 167  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   4    ‘    SS        3         1
# 168  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   5  남동구   NNP        3         2
#                  doc_id             sentence_id  \
# 169  NWRW1800000044.248  NWRW1800000044.248.9.1
# 170  NWRW1800000044.248  NWRW1800000044.248.9.1
# 171  NWRW1800000044.248  NWRW1800000044.248.9.1
# 172  NWRW1800000044.248  NWRW1800000044.248.9.1
# 173  NWRW1800000044.248  NWRW1800000044.248.9.1
# 174  NWRW1800000044.248  NWRW1800000044.248.9.1
# 175  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 169  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   6    동   NNG        4         1
# 170  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   7    (    SS        4         2
# 171  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   8    洞    SH        4         3
# 172  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.   9    )    SS        4         4
# 173  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  10   복지   NNG        4         5
# 174  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  11  위원회   NNG        4         6
# 175  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  12    ’    SS        4         7
#                  doc_id             sentence_id  \
# 176  NWRW1800000044.248  NWRW1800000044.248.9.1
# 177  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 176  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  13   폐지   NNG        5         1
# 177  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  14    를   JKO        5         2
#                  doc_id             sentence_id  \
# 178  NWRW1800000044.248  NWRW1800000044.248.9.1
# 179  NWRW1800000044.248  NWRW1800000044.248.9.1
# 180  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 178  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  15   추진   NNG        6         1
# 179  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  16    하   XSV        6         2
# 180  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  17    고    EC        6         3
#                  doc_id             sentence_id  \
# 181  NWRW1800000044.248  NWRW1800000044.248.9.1
# 182  NWRW1800000044.248  NWRW1800000044.248.9.1
# 183  NWRW1800000044.248  NWRW1800000044.248.9.1
#
#                                 sentence  id form label  word_id  position
# 181  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  18    있    VX        7         1
# 182  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  19    다    EF        7         2
# 183  남동구는 또 ‘남동구 동(洞)복지위원회’ 폐지를 추진하고 있다.  20    .    SF        7         3
# 이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체에 인적 안전망을 구축하라는 공문을 보내며 ‘모범사례’로 제시한 것이다.
#                  doc_id             sentence_id  \
# 184  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 184  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   1    이   MMD
#
#      word_id  position
# 184        1         1
#                  doc_id             sentence_id  \
# 185  NWRW1800000044.248  NWRW1800000044.248.9.2
# 186  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 185  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   2  위원회   NNG
# 186  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   3    는    JX
#
#      word_id  position
# 185        2         1
# 186        2         2
#                  doc_id             sentence_id  \
# 187  NWRW1800000044.248  NWRW1800000044.248.9.2
# 188  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 187  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   4   지나    VV
# 188  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   5    ㄴ   ETM
#
#      word_id  position
# 187        3         1
# 188        3         2
#                  doc_id             sentence_id  \
# 189  NWRW1800000044.248  NWRW1800000044.248.9.2
# 190  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 189  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   6    3    SN
# 190  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   7    월   NNB
#
#      word_id  position
# 189        4         1
# 190        4         2
#                  doc_id             sentence_id  \
# 191  NWRW1800000044.248  NWRW1800000044.248.9.2
# 192  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 191  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   8    ‘    SS
# 192  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...   9  송파구   NNP
#
#      word_id  position
# 191        5         1
# 192        5         2
#                  doc_id             sentence_id  \
# 193  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 193  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  10    세   MMN
#
#      word_id  position
# 193        6         1
#                  doc_id             sentence_id  \
# 194  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 194  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  11   모녀   NNG
#
#      word_id  position
# 194        7         1
#                  doc_id             sentence_id  \
# 195  NWRW1800000044.248  NWRW1800000044.248.9.2
# 196  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 195  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  12   사건   NNG
# 196  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  13    ’    SS
#
#      word_id  position
# 195        8         1
# 196        8         2
#                  doc_id             sentence_id  \
# 197  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 197  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  14   이후   NNG
#
#      word_id  position
# 197        9         1
#                  doc_id             sentence_id  \
# 198  NWRW1800000044.248  NWRW1800000044.248.9.2
# 199  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 198  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  15   정부   NNG
# 199  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  16    가   JKS
#
#      word_id  position
# 198       10         1
# 199       10         2
#                  doc_id             sentence_id  \
# 200  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 200  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  17   전국   NNG
#
#      word_id  position
# 200       11         1
#                  doc_id             sentence_id  \
# 201  NWRW1800000044.248  NWRW1800000044.248.9.2
# 202  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 201  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  18  232    SN
# 202  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  19    개   NNB
#
#      word_id  position
# 201       12         1
# 202       12         2
#                  doc_id             sentence_id  \
# 203  NWRW1800000044.248  NWRW1800000044.248.9.2
# 204  NWRW1800000044.248  NWRW1800000044.248.9.2
# 205  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 203  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  20   자치   NNG
# 204  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  21   단체   NNG
# 205  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  22    에   JKB
#
#      word_id  position
# 203       13         1
# 204       13         2
# 205       13         3
#                  doc_id             sentence_id  \
# 206  NWRW1800000044.248  NWRW1800000044.248.9.2
# 207  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 206  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  23    인   NNG
# 207  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  24    적   XSN
#
#      word_id  position
# 206       14         1
# 207       14         2
#                  doc_id             sentence_id  \
# 208  NWRW1800000044.248  NWRW1800000044.248.9.2
# 209  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 208  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  25  안전망   NNG
# 209  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  26    을   JKO
#
#      word_id  position
# 208       15         1
# 209       15         2
#                  doc_id             sentence_id  \
# 210  NWRW1800000044.248  NWRW1800000044.248.9.2
# 211  NWRW1800000044.248  NWRW1800000044.248.9.2
# 212  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 210  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  27   구축   NNG
# 211  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  28    하   XSV
# 212  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  29   라는   ETM
#
#      word_id  position
# 210       16         1
# 211       16         2
# 212       16         3
#                  doc_id             sentence_id  \
# 213  NWRW1800000044.248  NWRW1800000044.248.9.2
# 214  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 213  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  30   공문   NNG
# 214  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  31    을   JKO
#
#      word_id  position
# 213       17         1
# 214       17         2
#                  doc_id             sentence_id  \
# 215  NWRW1800000044.248  NWRW1800000044.248.9.2
# 216  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 215  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  32   보내    VV
# 216  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  33    며    EC
#
#      word_id  position
# 215       18         1
# 216       18         2
#                  doc_id             sentence_id  \
# 217  NWRW1800000044.248  NWRW1800000044.248.9.2
# 218  NWRW1800000044.248  NWRW1800000044.248.9.2
# 219  NWRW1800000044.248  NWRW1800000044.248.9.2
# 220  NWRW1800000044.248  NWRW1800000044.248.9.2
# 221  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 217  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  34    ‘    SS
# 218  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  35   모범   NNG
# 219  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  36   사례   NNG
# 220  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  37    ’    SS
# 221  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  38    로   JKB
#
#      word_id  position
# 217       19         1
# 218       19         2
# 219       19         3
# 220       19         4
# 221       19         5
#                  doc_id             sentence_id  \
# 222  NWRW1800000044.248  NWRW1800000044.248.9.2
# 223  NWRW1800000044.248  NWRW1800000044.248.9.2
# 224  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 222  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  39   제시   NNG
# 223  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  40    하   XSV
# 224  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  41    ㄴ   ETM
#
#      word_id  position
# 222       20         1
# 223       20         2
# 224       20         3
#                  doc_id             sentence_id  \
# 225  NWRW1800000044.248  NWRW1800000044.248.9.2
# 226  NWRW1800000044.248  NWRW1800000044.248.9.2
# 227  NWRW1800000044.248  NWRW1800000044.248.9.2
# 228  NWRW1800000044.248  NWRW1800000044.248.9.2
#
#                                               sentence  id form label  \
# 225  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  42    것   NNB
# 226  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  43    이   VCP
# 227  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  44    다    EF
# 228  이 위원회는 지난 3월 ‘송파구 세 모녀 사건’ 이후 정부가 전국 232개 자치단체...  45    .    SF
#
#      word_id  position
# 225       21         1
# 226       21         2
# 227       21         3
# 228       21         4
# 복지 사각지대 주민을 발굴해 지원하고, 지역 주민들 스스로 기금을 모아 위급 상황이 발생하면 신속히 쓸 수 있도록 하는 기능을 맡고 있다.
#                  doc_id             sentence_id  \
# 229  NWRW1800000044.248  NWRW1800000044.248.9.3
#
# ...
# 278        5         1
# 279        5         2
#                  doc_id             sentence_id  \
# 280  NWRW1800000044.248  NWRW1800000044.248.9.4
# 281  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 280  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  12    있    VX
# 281  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  13   다며    EC
#
#      word_id  position
# 280        6         1
# 281        6         2
#                  doc_id             sentence_id  \
# 282  NWRW1800000044.248  NWRW1800000044.248.9.4
# 283  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 282  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  14   폐지   NNG
# 283  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  15    를   JKO
#
#      word_id  position
# 282        7         1
# 283        7         2
#                  doc_id             sentence_id  \
# 284  NWRW1800000044.248  NWRW1800000044.248.9.4
# 285  NWRW1800000044.248  NWRW1800000044.248.9.4
# 286  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 284  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  16   추진   NNG
# 285  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  17    하   XSV
# 286  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  18    고    EC
#
#      word_id  position
# 284        8         1
# 285        8         2
# 286        8         3
#                  doc_id             sentence_id  \
# 287  NWRW1800000044.248  NWRW1800000044.248.9.4
# 288  NWRW1800000044.248  NWRW1800000044.248.9.4
# 289  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 287  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  19    있    VX
# 288  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  20   지만    EC
# 289  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  21    ,    SP
#
#      word_id  position
# 287        9         1
# 288        9         2
# 289        9         3
#                  doc_id             sentence_id  \
# 290  NWRW1800000044.248  NWRW1800000044.248.9.4
# 291  NWRW1800000044.248  NWRW1800000044.248.9.4
# 292  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 290  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  22   주민   NNG
# 291  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  23    들   XSN
# 292  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  24    은    JX
#
#      word_id  position
# 290       10         1
# 291       10         2
# 292       10         3
#                  doc_id             sentence_id  \
# 293  NWRW1800000044.248  NWRW1800000044.248.9.4
# 294  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 293  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  25    “    SS
# 294  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  26   지역   NNG
#
#      word_id  position
# 293       11         1
# 294       11         2
#                  doc_id             sentence_id  \
# 295  NWRW1800000044.248  NWRW1800000044.248.9.4
# 296  NWRW1800000044.248  NWRW1800000044.248.9.4
# 297  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 295  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  27   유지   NNG
# 296  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  28    들   XSN
# 297  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  29    로   JKB
#
#      word_id  position
# 295       12         1
# 296       12         2
# 297       12         3
#                  doc_id             sentence_id  \
# 298  NWRW1800000044.248  NWRW1800000044.248.9.4
# 299  NWRW1800000044.248  NWRW1800000044.248.9.4
# 300  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 298  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  30   구성   NNG
# 299  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  31    되   XSV
# 300  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  32    어    EC
#
#      word_id  position
# 298       13         1
# 299       13         2
# 300       13         3
#                  doc_id             sentence_id  \
# 301  NWRW1800000044.248  NWRW1800000044.248.9.4
# 302  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 301  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  33   사실   NNG
# 302  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  34    상   XSN
#
#      word_id  position
# 301       14         1
# 302       14         2
#                  doc_id             sentence_id  \
# 303  NWRW1800000044.248  NWRW1800000044.248.9.4
# 304  NWRW1800000044.248  NWRW1800000044.248.9.4
# 305  NWRW1800000044.248  NWRW1800000044.248.9.4
# 306  NWRW1800000044.248  NWRW1800000044.248.9.4
# 307  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id  form label  \
# 303  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  35  유명무실   NNG
# 304  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  36     하   XSA
# 305  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  37     아    EC
# 306  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  38     지    VX
# 307  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  39     ㄴ   ETM
#
#      word_id  position
# 303       15         1
# 304       15         2
# 305       15         3
# 306       15         4
# 307       15         5
#                  doc_id             sentence_id  \
# 308  NWRW1800000044.248  NWRW1800000044.248.9.4
# 309  NWRW1800000044.248  NWRW1800000044.248.9.4
# 310  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 308  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  40   주민   NNG
# 309  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  41  자치위   NNG
# 310  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  42    에   JKB
#
#      word_id  position
# 308       16         1
# 309       16         2
# 310       16         3
#                  doc_id             sentence_id  \
# 311  NWRW1800000044.248  NWRW1800000044.248.9.4
# 312  NWRW1800000044.248  NWRW1800000044.248.9.4
# 313  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 311  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  43   복지   NNG
# 312  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  44  위원회   NNG
# 313  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  45    를   JKO
#
#      word_id  position
# 311       17         1
# 312       17         2
# 313       17         3
#                  doc_id             sentence_id  \
# 314  NWRW1800000044.248  NWRW1800000044.248.9.4
# 315  NWRW1800000044.248  NWRW1800000044.248.9.4
# 316  NWRW1800000044.248  NWRW1800000044.248.9.4
# 317  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 314  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  46   흡수   NNG
# 315  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  47    하   XSV
# 316  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  48    겠    EP
# 317  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  49   다는   ETM
#
#      word_id  position
# 314       18         1
# 315       18         2
# 316       18         3
# 317       18         4
#                  doc_id             sentence_id  \
# 318  NWRW1800000044.248  NWRW1800000044.248.9.4
# 319  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 318  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  50    거   NNB
# 319  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  51    ㄴ    JX
#
#      word_id  position
# 318       19         1
# 319       19         2
#                  doc_id             sentence_id  \
# 320  NWRW1800000044.248  NWRW1800000044.248.9.4
# 321  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 320  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  52   사실   NNG
# 321  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  53    상   XSN
#
#      word_id  position
# 320       20         1
# 321       20         2
#                  doc_id             sentence_id  \
# 322  NWRW1800000044.248  NWRW1800000044.248.9.4
# 323  NWRW1800000044.248  NWRW1800000044.248.9.4
# 324  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 322  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  54   없애    VV
# 323  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  55    겠    EP
# 324  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  56   다는   ETM
#
#      word_id  position
# 322       21         1
# 323       21         2
# 324       21         3
#                  doc_id             sentence_id  \
# 325  NWRW1800000044.248  NWRW1800000044.248.9.4
# 326  NWRW1800000044.248  NWRW1800000044.248.9.4
# 327  NWRW1800000044.248  NWRW1800000044.248.9.4
# 328  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 325  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  57    것   NNB
# 326  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  58    ”    SS
# 327  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  59    이   VCP
# 328  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  60   라며    EC
#
#      word_id  position
# 325       22         1
# 326       22         2
# 327       22         3
# 328       22         4
#                  doc_id             sentence_id  \
# 329  NWRW1800000044.248  NWRW1800000044.248.9.4
# 330  NWRW1800000044.248  NWRW1800000044.248.9.4
# 331  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 329  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  61   반발   NNG
# 330  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  62    하   XSV
# 331  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  63    고    EC
#
#      word_id  position
# 329       23         1
# 330       23         2
# 331       23         3
#                  doc_id             sentence_id  \
# 332  NWRW1800000044.248  NWRW1800000044.248.9.4
# 333  NWRW1800000044.248  NWRW1800000044.248.9.4
# 334  NWRW1800000044.248  NWRW1800000044.248.9.4
#
#                                               sentence  id form label  \
# 332  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  64    있    VX
# 333  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  65    다    EF
# 334  남동구는 주민자치위원회가 그런 기능을 하고 있다며 폐지를 추진하고 있지만, 주민들은...  66    .    SF
#
#      word_id  position
# 332       24         1
# 333       24         2
# 334       24         3
# 신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사
#                  doc_id             sentence_id  \
# 335  NWRW1800000037.354  NWRW1800000037.354.1.1
# 336  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id  form label  word_id  position
# 335  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   1  신한은행   NNP        1         1
# 336  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   2     도    JX        1         2
#                  doc_id             sentence_id  \
# 337  NWRW1800000037.354  NWRW1800000037.354.1.1
# 338  NWRW1800000037.354  NWRW1800000037.354.1.1
# 339  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 337  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   3   압수   NNG        2         1
# 338  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   4   수색   NNG        2         2
# 339  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   5    …    SE        2         3
#                  doc_id             sentence_id  \
# 340  NWRW1800000037.354  NWRW1800000037.354.1.1
# 341  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 340  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   6    ‘    SS        3         1
# 341  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   7    팬   NNG        3         2
#                  doc_id             sentence_id  \
# 342  NWRW1800000037.354  NWRW1800000037.354.1.1
# 343  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 342  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   8   재팬   NNP        4         1
# 343  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사   9    ’    SS        4         2
#                  doc_id             sentence_id  \
# 344  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 344  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사  10   대출   NNG        5         1
#                  doc_id             sentence_id  \
# 345  NWRW1800000037.354  NWRW1800000037.354.1.1
# 346  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 345  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사  11   통하    VV        6         1
# 346  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사  12    ㄴ   ETM        6         2
#                  doc_id             sentence_id  \
# 347  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 347  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사  13  돈세탁   NNG        7         1
#                  doc_id             sentence_id  \
# 348  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 348  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사  14   여부   NNG        8         1
#                  doc_id             sentence_id  \
# 349  NWRW1800000037.354  NWRW1800000037.354.1.1
#
#                                sentence  id form label  word_id  position
# 349  신한은행도 압수수색… ‘팬 재팬’ 대출 통한 돈세탁 여부 수사  15   수사   NNG        9         1
# ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성
#                  doc_id             sentence_id                 sentence  id  \
# 350  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   1
# 351  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   2
#
#     form label  word_id  position
# 350    ‘    SS        1         1
# 351    팬   NNG        1         2
#                  doc_id             sentence_id                 sentence  id  \
# 352  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   3
# 353  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   4
#
#     form label  word_id  position
# 352   재팬   NNP        2         1
# 353    ’    SS        2         2
#                  doc_id             sentence_id                 sentence  id  \
# 354  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   5
# 355  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   6
#
#      form label  word_id  position
# 354  부동산업   NNG        3         1
# 355     …    SE        3         2
#                  doc_id             sentence_id                 sentence  id  \
# 356  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   7
# 357  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   8
#
#     form label  word_id  position
# 356  페이퍼   NNG        4         1
# 357  컴퍼니   NNG        4         2
#                  doc_id             sentence_id                 sentence  id  \
# 358  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성   9
# 359  NWRW1800000037.354  NWRW1800000037.354.2.1  ‘팬 재팬’ 부동산업… 페이퍼컴퍼니 가능성  10
#
#     form label  word_id  position
# 358   가능   NNG        5         1
# 359    성   XSN        5         2

# %%
'''
tag_syllable = {sentence : {
                            index : word,
                            }
                }
'''
tag_syllable = {}
times = 0
for id in sentence_id_list:
    id_x = 'NWRW1800000032.388.4.1'
    sub_df = df[df['sentence_id']==id_x]
    #sub_df = df[df['sentence_id']==id]
    sentence = sub_df.reset_index().iloc[0]['sentence']
    tag_syllable[sentence] = {}
    splitted_sentence = sentence.split(" ")
    print(splitted_sentence)
    idx = 0
    
    for i in range(len(splitted_sentence)):
        temp = sub_df[sub_df['word_id'] == i+1]
        print('NNB' in temp['label'])
        print(temp['label'].iloc[0])
        if temp.empty:
            idx += len(splitted_sentence[i]) + 1    
            continue
        else:
            for j in range(len(temp)):
                if 'NNB' in temp.iloc[j]['label']  or 'NNG' in temp.iloc[j]['label'] or 'NNP' in temp.iloc[j]['label']:
                    tag_syllable[sentence][idx] = temp.iloc[j]['form']
                    idx += len(temp.iloc[j]['form'])
            idx += 1
    break
# Out:
# ['24일', '치러진', '무상급식', '주민투표가', '투표율', '미달로', '무산됐음에도', '서울시가', '초등학교', '5~6학년', '20만여명의', '무상급식', '예산', '695억원을', '집행할', '수', '없다는', '뜻을', '분명히', '했다.']
# False
# SN
# False
# VV
# False
# NNG
# False
# NNG
# False
# NNG
# False
# NNG
# False
# NNG
# False
# NNP
# False
# NNG
# False
# SN
# False
# SN
# False
# NNG
# False
# NNG
# False
# SN
# False
# NNG
# False
# NNB
# False
# VA
# False
# NNG
# False
# MAG
# False
# VV

# %%
model = fasttext.train_unsupervised('decomposed_sent.txt', dim = 100, epoch = 10)

# %%
model.save_model('fasttext_jn.bin')

# %%
df_name = '../NIKL_MP_CSV/NXMP1902008040_{}.csv'
with open('decomposed_sent.txt', 'w') as f:
    for i in range(5):
        df = pd.read_csv(df_name.format(i + 1), skipinitialspace=True, usecols=('sentence_id', 'form'))
        sent_form={}
        pre_sent = ''
        
        for value in tqdm(df.values):
            sent, form = value[0], value[1]
            if pre_sent != sent:
                sent_form[sent] = []
                pre_sent = sent
            sent_form[sent].append(form)
            
        for form in tqdm(sent_form.values()):
            f.write(' '.join(decompose(form)) + '\n')

# %%
from khaiii import KhaiiiApi

# %%
khaiiiapi = KhaiiiApi()

# %%
df_stopwords = pd.read_table('stopwords_with_tag.txt')

# %%
stopwords = []
for morph, tag in zip(df_stopwords['morph'], df_stopwords['tag']):
    stopword_morph_tag = f'{morph}/{tag}'
    stopwords.append(stopword_morph_tag)

# %%
i = 0 
morphologized_sent = []
for line in tqdm(concated['document']):
    temp = ''
    for word in khaiiiapi.analyze(line):
        temp += ' '.join([m.lex for m in word.morphs if m.lex not in stopwords]) + ' '
    morphologized_sent.append(temp.rstrip())
