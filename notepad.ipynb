# %%
import pandas as pd

# %%
df = pd.read_csv('./yellower.csv', encoding='UTF-8')

# %%
df
# Out:
#         Day           단어                       뜻  외움 Unnamed: 4  Unnamed: 5
# 0      day1       resume                     이력서 NaN        NaN         NaN
# 1      day1    applicant                지원자, 신청자 NaN        NaN         NaN
# 2      day1  requirement                필요조건, 요건 NaN        NaN         NaN
# 3      day1         meet         (필요,요구 등을)만족시키다 NaN        NaN         NaN
# 4      day1    qualified               자격있는, 적격의 NaN        NaN         NaN
# ...     ...          ...                     ...  ..        ...         ...
# 1217  day30       induce   유발하다 (reduce줄이다, 낮추다) NaN        NaN         NaN
# 1218  day30    insurance                      보험 NaN        NaN         NaN
# 1219  day30    nutrition                      영양 NaN        NaN         NaN
# 1220  day30   prevention  예방(prevent 예방하다, 방해하다) NaN        NaN         NaN
# 1221  day30  susceptible    ~에 감염되기 쉬운, 영향 받기 쉬운 NaN        NaN         NaN
#
# [1222 rows x 6 columns]

# %%
df = df.dropna(1)

# %%
df
# Out:
#         Day           단어                       뜻
# 0      day1       resume                     이력서
# 1      day1    applicant                지원자, 신청자
# 2      day1  requirement                필요조건, 요건
# 3      day1         meet         (필요,요구 등을)만족시키다
# 4      day1    qualified               자격있는, 적격의
# ...     ...          ...                     ...
# 1217  day30       induce   유발하다 (reduce줄이다, 낮추다)
# 1218  day30    insurance                      보험
# 1219  day30    nutrition                      영양
# 1220  day30   prevention  예방(prevent 예방하다, 방해하다)
# 1221  day30  susceptible    ~에 감염되기 쉬운, 영향 받기 쉬운
#
# [1222 rows x 3 columns]

# %%
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.26.18) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %%
df.sort_values(by=['뜻'])
# Out:
#         Day          단어                        뜻
# 740   day19        sale     (-s)매출액, 매상고; (할인)판매
# 1003  day25        head    (~의 방향으로)나아가다, 향하게 하다
# 535   day14      locate  (~의 위치를)찾아내다;\n~을 위치시키다
# 364   day10  affordable       (가격이)알맞은, 감당할 수 있는
# 223    day6     edition                  (간행물의)판
# ...     ...         ...                      ...
# 1067  day27     sponsor                후원하다, 후원자
# 16     day1   excellent                      훌륭한
# 723   day18        stir                 휘젓다, 뒤섞다
# 902   day23       leave             휴가, 떠나다, 남기다
# 788   day20      browse               흝어보다, 둘러보다
#
# [1222 rows x 3 columns]

# %%
model = Word2Vec(sentences=result, size=100, window=5, min_count=1, workers=2)

# %%
model.corpus_count
# Out:
# 1222

# %%
model.vocabulary
